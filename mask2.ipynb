# %%
# !git clone https://github.com/its-harshil/face-mask-detector.git
# Out:
# Cloning into 'face-mask-detector'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
# !python face-mask-detector/detect_mask_video.py
# Out:
# 2020-12-02 03:23:33.496786: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# [INFO] loading face detector model...
# Traceback (most recent call last):
#   File "face-mask-detector/detect_mask_video.py", line 91, in <module>
#     faceNet = cv2.dnn.readNet(prototxtPath, weightsPath)
# cv2.error: OpenCV(4.1.2) /io/opencv/modules/dnn/src/caffe/caffe_io.cpp:1121: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "face_detector/deploy.prototxt" in function 'ReadProtoFromTextFile'
